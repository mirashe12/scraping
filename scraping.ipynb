# %%
from bs4 import BeautifulSoup
import os
import pandas as pd
import numpy as np

# %%
pip install requests
# Out:
# ...
# Note: you may need to restart the kernel to use updated packages.
# [notice] A new release of pip is available: 23.2.1 -> 23.3.2
# [notice] To update, run: python.exe -m pip install --upgrade pip

# %%
import requests

# %%
df=pd.read_csv("links.csv")

# %%
links=df['URL']

# %%
os.mkdir("txt_files")

# %%
count=0

# %%
for count, link in enumerate(links, start=1):
    print(f"Processing link {count}: {link}")
    response = requests.get(link)

    if response.status_code == 200:
        soup = BeautifulSoup(response.text)
        title_tag = soup.title
        title = title_tag.get_text()
        text_tags = soup.find_all('p')
        text = '\n'.join([tag.text for tag in text_tags])
        combined_content = f"{title}\n\n{text}"

        cleaned_lines = combined_content.split('\n')[:-2]
        cleaned_text = '\n'.join(cleaned_lines)

        file = f"{count}.txt"
        file_path = os.path.join("txt_files", file)

        with open(file_path, 'w', encoding='utf-8') as file:
            file.write(cleaned_text)
        print(f"Successfully processed link {count}")
    else:
        print(f"Failed to fetch content from {link}")
# Out:
# Processing link 1: https://insights.blackcoffer.com/rising-it-cities-and-its-impact-on-the-economy-environment-infrastructure-and-city-life-by-the-year-2040-2/
# Successfully processed link 1
# Processing link 2: https://insights.blackcoffer.com/rising-it-cities-and-their-impact-on-the-economy-environment-infrastructure-and-city-life-in-future/
# Successfully processed link 2
# Processing link 3: https://insights.blackcoffer.com/internet-demands-evolution-communication-impact-and-2035s-alternative-pathways/
# Successfully processed link 3
# Processing link 4: https://insights.blackcoffer.com/rise-of-cybercrime-and-its-effect-in-upcoming-future/
# Successfully processed link 4
# Processing link 5: https://insights.blackcoffer.com/ott-platform-and-its-impact-on-the-entertainment-industry-in-future/
# Successfully processed link 5
# Processing link 6: https://insights.blackcoffer.com/the-rise-of-the-ott-platform-and-its-impact-on-the-entertainment-industry-by-2040/
# ...
