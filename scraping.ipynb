# %%
from bs4 import BeautifulSoup
import os
import pandas as pd
import numpy as np

# %%
pip install requests
# Out:
# ...
#
# ...
# [notice] A new release of pip is available: 23.2.1 -> 23.3.2
# [notice] To update, run: python.exe -m pip install --upgrade pip

# %%
import requests

# %%
df=pd.read_csv("links.csv")

# %%
links=df['URL']

# %%
os.mkdir("txt_files")
# Out:
# ---------------------------------------------------------------------------
# FileExistsError                           Traceback (most recent call last)
# Cell In[7], line 1
# ----> 1 os.mkdir("txt_files")
#
# FileExistsError: [WinError 183] Cannot create a file when that file already exists: 'txt_files'

# %%
count=0

# %%
import requests
from bs4 import BeautifulSoup
import os
import pandas as pd

# Assuming links is a DataFrame with columns 'URL_ID' and 'URL'
links = pd.read_csv('links.csv')  # Replace 'your_links.csv' with the actual CSV file path

output_directory = "txt_files"

# Create the output directory if it doesn't exist
if not os.path.exists(output_directory):
    os.makedirs(output_directory)

for index, row in links.iterrows():
    url_id = row['URL_ID']
    link = row['URL']

    print(f"Processing link {url_id}: {link}")
    response = requests.get(link)

    if response.status_code == 200:
        soup = BeautifulSoup(response.text, 'html.parser')  # Specify the parser
        title_tag = soup.title
        title = title_tag.get_text()
        text_tags = soup.find_all('p')
        text = '\n'.join([tag.text for tag in text_tags])
        combined_content = f"{title}\n\n{text}"

        # Remove lines 3 to 18 and the last 2 lines
        cleaned_lines = combined_content.split('\n')
        cleaned_lines = cleaned_lines[:2] + cleaned_lines[18:-2]

        cleaned_text = '\n'.join(cleaned_lines)

        file_name = f"{url_id}.txt"  # Use URL_ID as the file name
        file_path = os.path.join(output_directory, file_name)

        with open(file_path, 'w', encoding='utf-8') as file:
            file.write(cleaned_text)
        print(f"Successfully processed link {url_id}")
    else:
        print(f"Failed to fetch content from {link}")
# Out:
# Processing link blackassign0001: https://insights.blackcoffer.com/rising-it-cities-and-its-impact-on-the-economy-environment-infrastructure-and-city-life-by-the-year-2040-2/
# Successfully processed link blackassign0001
# Processing link blackassign0002: https://insights.blackcoffer.com/rising-it-cities-and-their-impact-on-the-economy-environment-infrastructure-and-city-life-in-future/
# Successfully processed link blackassign0002
# Processing link blackassign0003: https://insights.blackcoffer.com/internet-demands-evolution-communication-impact-and-2035s-alternative-pathways/
# Successfully processed link blackassign0003
# Processing link blackassign0004: https://insights.blackcoffer.com/rise-of-cybercrime-and-its-effect-in-upcoming-future/
# Successfully processed link blackassign0004
# Processing link blackassign0005: https://insights.blackcoffer.com/ott-platform-and-its-impact-on-the-entertainment-industry-in-future/
# Successfully processed link blackassign0005
# ...
